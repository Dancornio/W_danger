# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import os

# %%
dt_bahia = pd.read_csv("../../data/raw/mortes_violentas_estado.csv", sep=",", encoding="latin-1")
dt_bahia.head()
# Out:
#    ANO_1  ID_REGIAO    REGIAO  ID_MUNICIPIO   MUNICIPIO   ANO  MES  \
# 0   2026          3  Interior        290020       Abare  2026    1
# 1   2024          3  Interior        290030   Acajutiba  2024    1
# 2   2025          3  Interior        290030   Acajutiba  2025    1
# 3   2026          3  Interior        290040   Agua Fria  2026    1
# 4   2025          3  Interior        290070  Alagoinhas  2025    1
#
#         GR_NATUREZA  QT_VITIMAS
# 0  HOMICIDIO DOLOSO           1
# 1  HOMICIDIO DOLOSO           2
# 2  HOMICIDIO DOLOSO           4
# 3  HOMICIDIO DOLOSO           2
# 4  HOMICIDIO DOLOSO           1
